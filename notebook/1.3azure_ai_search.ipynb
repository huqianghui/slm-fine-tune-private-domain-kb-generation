# %% [markdown]
# # Azure AI Search: vector search, step by step

# %% [markdown]
# ## Setup API client

# %%
import os

import dotenv
from azure.core.credentials import AzureKeyCredential
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents import SearchClient


dotenv.load_dotenv()

search_creds = AzureKeyCredential(os.getenv("AZURE_SEARCH_API_KEY"))
AZURE_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
index_client = SearchIndexClient(endpoint=AZURE_SEARCH_ENDPOINT, credential=search_creds)
AZURE_SEARCH_TINY_INDEX = "envision-qa-index"

# %% [markdown]
# ## Search a tiny index
#
# ### Create index

# %%
from azure.search.documents.indexes.models import (
    AzureOpenAIParameters,
    AzureOpenAIVectorizer,
    CorsOptions,
    HnswAlgorithmConfiguration,
    SearchableField,
    SearchField,
    SearchFieldDataType,
    SearchIndex,
    SemanticConfiguration,
    SemanticField,
    SemanticPrioritizedFields,
    SemanticSearch,
    SimpleField,
    VectorSearch,
    VectorSearchProfile
)

index = SearchIndex(
    name=AZURE_SEARCH_TINY_INDEX,
    cors_options = CorsOptions(allowed_origins=["*"], max_age_in_seconds=600), 
    fields=[
                SimpleField(name="id", type=SearchFieldDataType.String, key=True,searchable=True, filterable=True, sortable=True, facetable=True),
                SearchableField(name="question", filterable=True, sortable=True, facetable=True,type=SearchFieldDataType.String, analyzer_name="zh-Hans.microsoft"),
                SearchableField(name="answer", filterable=True, sortable=True, facetable=True,type=SearchFieldDataType.String, analyzer_name="zh-Hans.microsoft"),
                SearchableField(name="applicationType", filterable=True, sortable=True, facetable=True,type=SearchFieldDataType.String, analyzer_name="zh-Hans.microsoft"),
                SearchField(name="question_embedding", 
                            type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                            hidden=False, 
                            searchable=True, 
                            filterable=False, 
                            sortable=False, 
                            facetable=False,
                            vector_search_dimensions=1536, 
                            vector_search_profile_name="azureOpenAIHnswProfile"),
                SearchField(name="answer_embedding", 
                            type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                            hidden=False, 
                            searchable=True, 
                            filterable=False, 
                            sortable=False, 
                            facetable=False,
                            vector_search_dimensions=1536, 
                            vector_search_profile_name="azureOpenAIHnswProfile")
            ],
    semantic_search=SemanticSearch(
                configurations=[
                    SemanticConfiguration(
                        name="default",
                        prioritized_fields=SemanticPrioritizedFields(
                            title_field=SemanticField(field_name="question"),
                            content_fields=[
                                SemanticField(field_name="answer")
                            ],
                            keywords_fields=[
                                SemanticField(field_name="question")
                            ]
                        ),
                    )
                ]
            ),
    vector_search=VectorSearch(
                algorithms=[HnswAlgorithmConfiguration(name="myHnsw")],
                profiles=[VectorSearchProfile(name="azureOpenAIHnswProfile",algorithm_configuration_name="myHnsw",vectorizer="azureOpenAIVectorizer")],
                vectorizers=[
                    AzureOpenAIVectorizer(
                        name="azureOpenAIVectorizer",
                        azure_open_ai_parameters=AzureOpenAIParameters(
                            resource_uri=os.getenv("aoai_resource_uri"),
                            deployment_id=os.getenv("aoai_embedding_deployment_name"),
                            model_name=os.getenv("aoai_embedding_model_name"),
                            api_key=os.getenv("aozai_api_key")))
                ]
            )
)

index_client.create_or_update_index(index)

# %%
search_client = SearchClient(
    endpoint=AZURE_SEARCH_ENDPOINT,
    index_name=AZURE_SEARCH_TINY_INDEX,
    credential=search_creds,
)

from openai import AzureOpenAI

search_creds = AzureKeyCredential(os.getenv("AZURE_SEARCH_API_KEY"))
AZURE_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
index_client = SearchIndexClient(endpoint=AZURE_SEARCH_ENDPOINT, credential=search_creds)


aoai_client = AzureOpenAI(
        api_key=os.getenv("aozai_api_key"),  
        api_version=os.getenv("aoai_llm_api_version"),
        azure_endpoint=os.getenv("aoai_resource_uri")
    )

# %%
def generate_embeddings_with_client(texts, client):
    """Generate embeddings for a list of texts using Azure OpenAI client."""
    if not texts or all(not text or text.strip() == "" for text in texts):
        return [[] for _ in range(len(texts))]
    
    try:
        # Filter out empty texts to avoid API errors
        non_empty_texts = [text for text in texts if text and text.strip() != ""]
        indices = [i for i, text in enumerate(texts) if text and text.strip() != ""]
        
        if not non_empty_texts:
            return [[] for _ in range(len(texts))]
        
        # Get embeddings for non-empty texts
        response = client.embeddings.create(
            input=non_empty_texts,
            model=os.getenv("aoai_embedding_model_name")
        )
        
        # Reconstruct the result list with empty embeddings for empty texts
        result = [[] for _ in range(len(texts))]
        for idx, embedding_data in zip(indices, response.data):
            result[idx] = embedding_data.embedding
            
        return result
    except Exception as e:
        print(f"Error generating embeddings: {str(e)}")
        return [[] for _ in range(len(texts))]

# %%
def upload_document_into_azure_search(documents,batch_size:int=100):
    successful_uploads = 0
    failed_uploads = 0

    for i in range(0, len(documents), batch_size):
        batch = documents[i:i+batch_size]
        try:
            upload_result = search_client.upload_documents(batch)
            succeeded = sum(1 for result in upload_result if result.succeeded)
            successful_uploads += succeeded
            failed_uploads += len(batch) - succeeded
            print(f"Batch {i//batch_size + 1}: {succeeded}/{len(batch)} documents succeeded")
        except Exception as e:
            print(f"Failed to upload batch {i//batch_size + 1}: {str(e)}")
            failed_uploads += len(batch)

    # Display final results
    print("\nUpload Summary:")
    print(f"- Total documents: {len(documents)}")
    print(f"- Successfully uploaded: {successful_uploads}")
    print(f"- Failed: {failed_uploads}")

# %%
# 知识库---人工生成.xlsx 
import pandas as pd
excel_path = "/home/azureuser/slm-fine-tune-private-domain-kb-generation/raw_documents/excel/知识库---人工生成.xlsx"
df = pd.read_excel(excel_path)
# Convert all column headers to lowercase
df.columns = [col.lower().strip() for col in df.columns]


def prepare_kb_human_gen_documents(df):
    # Ensure the DataFrame is not empty
    if df.empty:
        raise ValueError("The DataFrame is empty. Please provide a valid DataFrame.")

    # Check for required columns
    required_columns = ["question", "answer", "metadata"]
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        raise ValueError(f"The following required columns are missing: {', '.join(missing_columns)}")

    # Prepare documents for upload
    documents = []
    total_rows = len(df)

    # Prepare batches of questions and answers for efficient embedding generation
    batch_size = 20  # Azure OpenAI can handle multiple inputs in one API call
    for i in range(0, total_rows, batch_size):
        batch_end = min(i + batch_size, total_rows)
        batch_df = df.iloc[i:batch_end]
        
        # Prepare lists of questions and answers
        questions = [str(row["question"]) if not pd.isna(row["question"]) else "" for _, row in batch_df.iterrows()]
        answers = [str(row["answer"]) if not pd.isna(row["answer"]) else "" for _, row in batch_df.iterrows()]
        
        # Generate embeddings in batch
        question_embeddings = generate_embeddings_with_client(questions, aoai_client)
        answer_embeddings = generate_embeddings_with_client(answers, aoai_client)
        
        print(f"Processed documents {i+1} to {batch_end} (batch {i//batch_size + 1})")
        
        # Create documents with embeddings
        for j, (_, row) in enumerate(batch_df.iterrows()):
            idx = i + j
            document = {
                "id": f"kb_human_gen_{idx}",
                "question": str(row["question"]) if not pd.isna(row["question"]) else "",
                "answer": str(row["answer"]) if not pd.isna(row["answer"]) else "",
                "applicationType": str(row["metadata"]) if not pd.isna(row["metadata"]) else "",
                "question_embedding": question_embeddings[j],
                "answer_embedding": answer_embeddings[j]
            }
            documents.append(document)

    print(f"Prepared {len(documents)} documents with embeddings")
    return documents


# get documents from excel
kb_human_gen_documents = prepare_kb_human_gen_documents(df)
# upload documents into azure search
upload_document_into_azure_search(kb_human_gen_documents, batch_size=100)

# %% [markdown]
# ### Insert a few documents with tiny vectors

# %%
# 知识库---ai生产.xlsx 
import pandas as pd
excel_path = "/home/azureuser/slm-fine-tune-private-domain-kb-generation/raw_documents/excel/知识库---ai生产.xlsx"
df = pd.read_excel(excel_path)
# Convert all column headers to lowercase
df.columns = [col.lower().strip() for col in df.columns]

print(df.columns)


def prepare_kb_ai_gen_documents(df):
    # Ensure the DataFrame is not empty
    if df.empty:
        raise ValueError("The DataFrame is empty. Please provide a valid DataFrame.")

    # Check for required columns
    required_columns = ["question", "answer"]
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        raise ValueError(f"The following required columns are missing: {', '.join(missing_columns)}")

    # Prepare documents for upload
    documents = []
    total_rows = len(df)

    # Prepare batches of questions and answers for efficient embedding generation
    batch_size = 20  # Azure OpenAI can handle multiple inputs in one API call
    for i in range(0, total_rows, batch_size):
        batch_end = min(i + batch_size, total_rows)
        batch_df = df.iloc[i:batch_end]
        
        # Prepare lists of questions and answers
        questions = [str(row["question"]) if not pd.isna(row["question"]) else "" for _, row in batch_df.iterrows()]
        answers = [str(row["answer"]) if not pd.isna(row["answer"]) else "" for _, row in batch_df.iterrows()]
        
        # Generate embeddings in batch
        question_embeddings = generate_embeddings_with_client(questions, aoai_client)
        answer_embeddings = generate_embeddings_with_client(answers, aoai_client)
        
        print(f"Processed documents {i+1} to {batch_end} (batch {i//batch_size + 1})")
        
        # Create documents with embeddings
        for j, (_, row) in enumerate(batch_df.iterrows()):
            idx = i + j
            document = {
                "id": f"kb_ai_gen_{idx}",
                "question": str(row["question"]) if not pd.isna(row["question"]) else "",
                "answer": str(row["answer"]) if not pd.isna(row["answer"]) else "",
                "applicationType": "",
                "question_embedding": question_embeddings[j],
                "answer_embedding": answer_embeddings[j]
            }
            documents.append(document)

    print(f"Prepared {len(documents)} documents with embeddings")
    return documents


# get documents from excel
kb_ai_gen_documents = prepare_kb_ai_gen_documents(df)
# upload documents into azure search
upload_document_into_azure_search(kb_ai_gen_documents, batch_size=100)
# Out:
# Index(['question', 'answer'], dtype='object')
# Processed documents 1 to 20 (batch 1)
# Processed documents 21 to 40 (batch 2)
# Processed documents 41 to 60 (batch 3)
# Processed documents 61 to 80 (batch 4)
# Processed documents 81 to 100 (batch 5)
# Processed documents 101 to 120 (batch 6)
# Processed documents 121 to 140 (batch 7)
# Processed documents 141 to 160 (batch 8)
# Processed documents 161 to 180 (batch 9)
# Processed documents 181 to 200 (batch 10)
# Processed documents 201 to 220 (batch 11)
# Processed documents 221 to 240 (batch 12)
# Processed documents 241 to 260 (batch 13)
# Processed documents 261 to 280 (batch 14)
# Processed documents 281 to 300 (batch 15)
# Processed documents 301 to 320 (batch 16)
# Processed documents 321 to 340 (batch 17)
# Processed documents 341 to 360 (batch 18)
# Processed documents 361 to 380 (batch 19)
# Processed documents 381 to 400 (batch 20)
# Processed documents 401 to 420 (batch 21)
# Processed documents 421 to 440 (batch 22)
# Processed documents 441 to 460 (batch 23)
# Processed documents 461 to 480 (batch 24)
# Processed documents 481 to 500 (batch 25)
# Processed documents 501 to 520 (batch 26)
# Processed documents 521 to 540 (batch 27)
# Processed documents 541 to 560 (batch 28)
# Processed documents 561 to 580 (batch 29)
# Processed documents 581 to 600 (batch 30)
# Processed documents 601 to 620 (batch 31)
# Processed documents 621 to 640 (batch 32)
# Processed documents 641 to 660 (batch 33)
# Processed documents 661 to 680 (batch 34)
# Processed documents 681 to 700 (batch 35)
# Processed documents 701 to 720 (batch 36)
# Processed documents 721 to 740 (batch 37)
# Processed documents 741 to 760 (batch 38)
# Processed documents 761 to 780 (batch 39)
# Processed documents 781 to 800 (batch 40)
# Processed documents 801 to 820 (batch 41)
# Processed documents 821 to 840 (batch 42)
# Processed documents 841 to 860 (batch 43)
# Processed documents 861 to 880 (batch 44)
# Processed documents 881 to 900 (batch 45)
# Processed documents 901 to 920 (batch 46)
# Processed documents 921 to 940 (batch 47)
# Processed documents 941 to 960 (batch 48)
# Processed documents 961 to 980 (batch 49)
# Processed documents 981 to 1000 (batch 50)
# Processed documents 1001 to 1020 (batch 51)
# Processed documents 1021 to 1040 (batch 52)
# Processed documents 1041 to 1060 (batch 53)
# Processed documents 1061 to 1080 (batch 54)
# Processed documents 1081 to 1100 (batch 55)
# Processed documents 1101 to 1120 (batch 56)
# Processed documents 1121 to 1140 (batch 57)
# Processed documents 1141 to 1160 (batch 58)
# Processed documents 1161 to 1180 (batch 59)
# Processed documents 1181 to 1200 (batch 60)
# Processed documents 1201 to 1220 (batch 61)
# Processed documents 1221 to 1240 (batch 62)
# Processed documents 1241 to 1260 (batch 63)
# Processed documents 1261 to 1280 (batch 64)
# Processed documents 1281 to 1300 (batch 65)
# Processed documents 1301 to 1320 (batch 66)
# Processed documents 1321 to 1340 (batch 67)
# Processed documents 1341 to 1360 (batch 68)
# Processed documents 1361 to 1380 (batch 69)
# Processed documents 1381 to 1400 (batch 70)
# Processed documents 1401 to 1420 (batch 71)
# Processed documents 1421 to 1440 (batch 72)
# Processed documents 1441 to 1460 (batch 73)
# Processed documents 1461 to 1480 (batch 74)
# Processed documents 1481 to 1500 (batch 75)
# Processed documents 1501 to 1520 (batch 76)
# Processed documents 1521 to 1540 (batch 77)
# Processed documents 1541 to 1560 (batch 78)
# Processed documents 1561 to 1580 (batch 79)
# Processed documents 1581 to 1600 (batch 80)
# Processed documents 1601 to 1620 (batch 81)
# Processed documents 1621 to 1640 (batch 82)
# Processed documents 1641 to 1660 (batch 83)
# Processed documents 1661 to 1680 (batch 84)
# Processed documents 1681 to 1700 (batch 85)
# Processed documents 1701 to 1720 (batch 86)
# Processed documents 1721 to 1740 (batch 87)
# Processed documents 1741 to 1760 (batch 88)
# Processed documents 1761 to 1780 (batch 89)
# Processed documents 1781 to 1800 (batch 90)
# Processed documents 1801 to 1820 (batch 91)
# Processed documents 1821 to 1840 (batch 92)
# Processed documents 1841 to 1860 (batch 93)
# Processed documents 1861 to 1880 (batch 94)
# Processed documents 1881 to 1900 (batch 95)
# Processed documents 1901 to 1920 (batch 96)
# Processed documents 1921 to 1940 (batch 97)
# Processed documents 1941 to 1960 (batch 98)
# Processed documents 1961 to 1980 (batch 99)
# Processed documents 1981 to 2000 (batch 100)
# Processed documents 2001 to 2020 (batch 101)
# Processed documents 2021 to 2040 (batch 102)
# Processed documents 2041 to 2060 (batch 103)
# Processed documents 2061 to 2080 (batch 104)
# Processed documents 2081 to 2100 (batch 105)
# Processed documents 2101 to 2120 (batch 106)
# Processed documents 2121 to 2140 (batch 107)
# Processed documents 2141 to 2160 (batch 108)
# Processed documents 2161 to 2180 (batch 109)
# Processed documents 2181 to 2200 (batch 110)
# Processed documents 2201 to 2220 (batch 111)
# Processed documents 2221 to 2240 (batch 112)
# Processed documents 2241 to 2260 (batch 113)
# Processed documents 2261 to 2280 (batch 114)
# Processed documents 2281 to 2300 (batch 115)
# Processed documents 2301 to 2320 (batch 116)
# Processed documents 2321 to 2340 (batch 117)
# Processed documents 2341 to 2360 (batch 118)
# Processed documents 2361 to 2380 (batch 119)
# Processed documents 2381 to 2400 (batch 120)
# Processed documents 2401 to 2420 (batch 121)
# Processed documents 2421 to 2440 (batch 122)
# Processed documents 2441 to 2460 (batch 123)
# Processed documents 2461 to 2480 (batch 124)
# Processed documents 2481 to 2500 (batch 125)
# Processed documents 2501 to 2520 (batch 126)
# Processed documents 2521 to 2540 (batch 127)
# Processed documents 2541 to 2560 (batch 128)
# Processed documents 2561 to 2580 (batch 129)
# Processed documents 2581 to 2600 (batch 130)
# Processed documents 2601 to 2620 (batch 131)
# Processed documents 2621 to 2640 (batch 132)
# Processed documents 2641 to 2660 (batch 133)
# Processed documents 2661 to 2680 (batch 134)
# Processed documents 2681 to 2700 (batch 135)
# Processed documents 2701 to 2720 (batch 136)
# Processed documents 2721 to 2740 (batch 137)
# Processed documents 2741 to 2760 (batch 138)
# Processed documents 2761 to 2780 (batch 139)
# Processed documents 2781 to 2800 (batch 140)
# Processed documents 2801 to 2820 (batch 141)
# Processed documents 2821 to 2840 (batch 142)
# Processed documents 2841 to 2860 (batch 143)
# Processed documents 2861 to 2880 (batch 144)
# Processed documents 2881 to 2900 (batch 145)
# Processed documents 2901 to 2920 (batch 146)
# Processed documents 2921 to 2940 (batch 147)
# Processed documents 2941 to 2960 (batch 148)
# Processed documents 2961 to 2980 (batch 149)
# Processed documents 2981 to 3000 (batch 150)
# Processed documents 3001 to 3020 (batch 151)
# Processed documents 3021 to 3040 (batch 152)
# Processed documents 3041 to 3060 (batch 153)
# Processed documents 3061 to 3080 (batch 154)
# Processed documents 3081 to 3100 (batch 155)
# Processed documents 3101 to 3120 (batch 156)
# Processed documents 3121 to 3140 (batch 157)
# Processed documents 3141 to 3160 (batch 158)
# Processed documents 3161 to 3180 (batch 159)
# Processed documents 3181 to 3200 (batch 160)
# Processed documents 3201 to 3220 (batch 161)
# Processed documents 3221 to 3240 (batch 162)
# Processed documents 3241 to 3260 (batch 163)
# Processed documents 3261 to 3280 (batch 164)
# Processed documents 3281 to 3300 (batch 165)
# Processed documents 3301 to 3320 (batch 166)
# Processed documents 3321 to 3340 (batch 167)
# Processed documents 3341 to 3360 (batch 168)
# Processed documents 3361 to 3380 (batch 169)
# Processed documents 3381 to 3400 (batch 170)
# Processed documents 3401 to 3420 (batch 171)
# Processed documents 3421 to 3440 (batch 172)
# Processed documents 3441 to 3460 (batch 173)
# Processed documents 3461 to 3480 (batch 174)
# Processed documents 3481 to 3500 (batch 175)
# Processed documents 3501 to 3520 (batch 176)
# Processed documents 3521 to 3540 (batch 177)
# Processed documents 3541 to 3560 (batch 178)
# Processed documents 3561 to 3580 (batch 179)
# Processed documents 3581 to 3600 (batch 180)
# Processed documents 3601 to 3620 (batch 181)
# Processed documents 3621 to 3640 (batch 182)
# Processed documents 3641 to 3660 (batch 183)
# Processed documents 3661 to 3680 (batch 184)
# Processed documents 3681 to 3700 (batch 185)
# Processed documents 3701 to 3720 (batch 186)
# Processed documents 3721 to 3740 (batch 187)
# Processed documents 3741 to 3760 (batch 188)
# Processed documents 3761 to 3780 (batch 189)
# Processed documents 3781 to 3800 (batch 190)
# Processed documents 3801 to 3820 (batch 191)
# Processed documents 3821 to 3840 (batch 192)
# Processed documents 3841 to 3860 (batch 193)
# Processed documents 3861 to 3880 (batch 194)
# Processed documents 3881 to 3900 (batch 195)
# Processed documents 3901 to 3920 (batch 196)
# Processed documents 3921 to 3940 (batch 197)
# Processed documents 3941 to 3960 (batch 198)
# Processed documents 3961 to 3980 (batch 199)
# Processed documents 3981 to 4000 (batch 200)
# Processed documents 4001 to 4020 (batch 201)
# Processed documents 4021 to 4040 (batch 202)
# Processed documents 4041 to 4060 (batch 203)
# Processed documents 4061 to 4080 (batch 204)
# Processed documents 4081 to 4100 (batch 205)
# Processed documents 4101 to 4120 (batch 206)
# Processed documents 4121 to 4140 (batch 207)
# Processed documents 4141 to 4160 (batch 208)
# Processed documents 4161 to 4180 (batch 209)
# Processed documents 4181 to 4200 (batch 210)
# Processed documents 4201 to 4220 (batch 211)
# Processed documents 4221 to 4240 (batch 212)
# Processed documents 4241 to 4260 (batch 213)
# Processed documents 4261 to 4280 (batch 214)
# Processed documents 4281 to 4300 (batch 215)
# Processed documents 4301 to 4320 (batch 216)
# Processed documents 4321 to 4340 (batch 217)
# Processed documents 4341 to 4360 (batch 218)
# Processed documents 4361 to 4380 (batch 219)
# Processed documents 4381 to 4400 (batch 220)
# Processed documents 4401 to 4420 (batch 221)
# Processed documents 4421 to 4440 (batch 222)
# Processed documents 4441 to 4460 (batch 223)
# Processed documents 4461 to 4480 (batch 224)
# Processed documents 4481 to 4500 (batch 225)
# Processed documents 4501 to 4520 (batch 226)
# Processed documents 4521 to 4540 (batch 227)
# Processed documents 4541 to 4560 (batch 228)
# Processed documents 4561 to 4580 (batch 229)
# Processed documents 4581 to 4600 (batch 230)
# Processed documents 4601 to 4620 (batch 231)
# Processed documents 4621 to 4640 (batch 232)
# Processed documents 4641 to 4660 (batch 233)
# Processed documents 4661 to 4680 (batch 234)
# Processed documents 4681 to 4700 (batch 235)
# Processed documents 4701 to 4720 (batch 236)
# Processed documents 4721 to 4740 (batch 237)
# Processed documents 4741 to 4760 (batch 238)
# Processed documents 4761 to 4780 (batch 239)
# Processed documents 4781 to 4800 (batch 240)
# Processed documents 4801 to 4820 (batch 241)
# Processed documents 4821 to 4840 (batch 242)
# Processed documents 4841 to 4860 (batch 243)
# Processed documents 4861 to 4880 (batch 244)
# Processed documents 4881 to 4900 (batch 245)
# Processed documents 4901 to 4920 (batch 246)
# Processed documents 4921 to 4940 (batch 247)
# Processed documents 4941 to 4960 (batch 248)
# Processed documents 4961 to 4980 (batch 249)
# Processed documents 4981 to 5000 (batch 250)
# Processed documents 5001 to 5020 (batch 251)
# Processed documents 5021 to 5040 (batch 252)
# Processed documents 5041 to 5060 (batch 253)
# Processed documents 5061 to 5080 (batch 254)
# Processed documents 5081 to 5100 (batch 255)
# Processed documents 5101 to 5120 (batch 256)
# Processed documents 5121 to 5140 (batch 257)
# Processed documents 5141 to 5160 (batch 258)
# Processed documents 5161 to 5180 (batch 259)
# Processed documents 5181 to 5200 (batch 260)
# Processed documents 5201 to 5220 (batch 261)
# Processed documents 5221 to 5240 (batch 262)
# Processed documents 5241 to 5260 (batch 263)
# Processed documents 5261 to 5280 (batch 264)
# Processed documents 5281 to 5300 (batch 265)
# Processed documents 5301 to 5320 (batch 266)
# Processed documents 5321 to 5340 (batch 267)
# Processed documents 5341 to 5360 (batch 268)
# Processed documents 5361 to 5380 (batch 269)
# Processed documents 5381 to 5400 (batch 270)
# Processed documents 5401 to 5420 (batch 271)
# Processed documents 5421 to 5440 (batch 272)
# Processed documents 5441 to 5460 (batch 273)
# Processed documents 5461 to 5480 (batch 274)
# Processed documents 5481 to 5500 (batch 275)
# Processed documents 5501 to 5520 (batch 276)
# Processed documents 5521 to 5540 (batch 277)
# Processed documents 5541 to 5560 (batch 278)
# Processed documents 5561 to 5580 (batch 279)
# Processed documents 5581 to 5600 (batch 280)
# Processed documents 5601 to 5620 (batch 281)
# Processed documents 5621 to 5640 (batch 282)
# Processed documents 5641 to 5660 (batch 283)
# Processed documents 5661 to 5680 (batch 284)
# Processed documents 5681 to 5700 (batch 285)
# Processed documents 5701 to 5720 (batch 286)
# Processed documents 5721 to 5740 (batch 287)
# Processed documents 5741 to 5760 (batch 288)
# Processed documents 5761 to 5780 (batch 289)
# Processed documents 5781 to 5800 (batch 290)
# Processed documents 5801 to 5820 (batch 291)
# Processed documents 5821 to 5840 (batch 292)
# Processed documents 5841 to 5860 (batch 293)
# Processed documents 5861 to 5880 (batch 294)
# Processed documents 5881 to 5900 (batch 295)
# Processed documents 5901 to 5920 (batch 296)
# Processed documents 5921 to 5940 (batch 297)
# Processed documents 5941 to 5960 (batch 298)
# Processed documents 5961 to 5980 (batch 299)
# Processed documents 5981 to 6000 (batch 300)
# Processed documents 6001 to 6020 (batch 301)
# Processed documents 6021 to 6040 (batch 302)
# Processed documents 6041 to 6060 (batch 303)
# Processed documents 6061 to 6080 (batch 304)
# Processed documents 6081 to 6100 (batch 305)
# Processed documents 6101 to 6120 (batch 306)
# Processed documents 6121 to 6140 (batch 307)
# Processed documents 6141 to 6160 (batch 308)
# Processed documents 6161 to 6180 (batch 309)
# Processed documents 6181 to 6200 (batch 310)
# Processed documents 6201 to 6220 (batch 311)
# Processed documents 6221 to 6240 (batch 312)
# Processed documents 6241 to 6260 (batch 313)
# Processed documents 6261 to 6280 (batch 314)
# Processed documents 6281 to 6300 (batch 315)
# Processed documents 6301 to 6320 (batch 316)
# Processed documents 6321 to 6340 (batch 317)
# Processed documents 6341 to 6360 (batch 318)
# Processed documents 6361 to 6380 (batch 319)
# Processed documents 6381 to 6400 (batch 320)
# Processed documents 6401 to 6420 (batch 321)
# Processed documents 6421 to 6440 (batch 322)
# Processed documents 6441 to 6460 (batch 323)
# Processed documents 6461 to 6480 (batch 324)
# Processed documents 6481 to 6500 (batch 325)
# Processed documents 6501 to 6520 (batch 326)
# Processed documents 6521 to 6540 (batch 327)
# Processed documents 6541 to 6560 (batch 328)
# Processed documents 6561 to 6580 (batch 329)
# Processed documents 6581 to 6600 (batch 330)
# Processed documents 6601 to 6620 (batch 331)
# Processed documents 6621 to 6640 (batch 332)
# Processed documents 6641 to 6660 (batch 333)
# Processed documents 6661 to 6680 (batch 334)
# Processed documents 6681 to 6700 (batch 335)
# Processed documents 6701 to 6720 (batch 336)
# Processed documents 6721 to 6740 (batch 337)
# Processed documents 6741 to 6760 (batch 338)
# Processed documents 6761 to 6780 (batch 339)
# Processed documents 6781 to 6800 (batch 340)
# Processed documents 6801 to 6820 (batch 341)
# Processed documents 6821 to 6840 (batch 342)
# Processed documents 6841 to 6860 (batch 343)
# Processed documents 6861 to 6880 (batch 344)
# Processed documents 6881 to 6900 (batch 345)
# Processed documents 6901 to 6920 (batch 346)
# Processed documents 6921 to 6940 (batch 347)
# Processed documents 6941 to 6960 (batch 348)
# Processed documents 6961 to 6980 (batch 349)
# Processed documents 6981 to 7000 (batch 350)
# Processed documents 7001 to 7020 (batch 351)
# Processed documents 7021 to 7040 (batch 352)
# Processed documents 7041 to 7060 (batch 353)
# Processed documents 7061 to 7080 (batch 354)
# Processed documents 7081 to 7100 (batch 355)
# Processed documents 7101 to 7120 (batch 356)
# Processed documents 7121 to 7140 (batch 357)
# Processed documents 7141 to 7160 (batch 358)
# Processed documents 7161 to 7180 (batch 359)
# Processed documents 7181 to 7200 (batch 360)
# Processed documents 7201 to 7220 (batch 361)
# Processed documents 7221 to 7240 (batch 362)
# Processed documents 7241 to 7260 (batch 363)
# Processed documents 7261 to 7280 (batch 364)
# Processed documents 7281 to 7300 (batch 365)
# Processed documents 7301 to 7320 (batch 366)
# Processed documents 7321 to 7340 (batch 367)
# Processed documents 7341 to 7360 (batch 368)
# Processed documents 7361 to 7380 (batch 369)
# Processed documents 7381 to 7400 (batch 370)
# Processed documents 7401 to 7420 (batch 371)
# Processed documents 7421 to 7440 (batch 372)
# Processed documents 7441 to 7460 (batch 373)
# Processed documents 7461 to 7480 (batch 374)
# Processed documents 7481 to 7500 (batch 375)
# Processed documents 7501 to 7520 (batch 376)
# Processed documents 7521 to 7540 (batch 377)
# Processed documents 7541 to 7560 (batch 378)
# Processed documents 7561 to 7580 (batch 379)
# Processed documents 7581 to 7600 (batch 380)
# Processed documents 7601 to 7620 (batch 381)
# Processed documents 7621 to 7640 (batch 382)
# Processed documents 7641 to 7660 (batch 383)
# Processed documents 7661 to 7680 (batch 384)
# Processed documents 7681 to 7700 (batch 385)
# Processed documents 7701 to 7720 (batch 386)
# Processed documents 7721 to 7740 (batch 387)
# Processed documents 7741 to 7760 (batch 388)
# Processed documents 7761 to 7780 (batch 389)
# Processed documents 7781 to 7800 (batch 390)
# Processed documents 7801 to 7820 (batch 391)
# Processed documents 7821 to 7840 (batch 392)
# Processed documents 7841 to 7860 (batch 393)
# Processed documents 7861 to 7880 (batch 394)
# Processed documents 7881 to 7900 (batch 395)
# Processed documents 7901 to 7920 (batch 396)
# Processed documents 7921 to 7940 (batch 397)
# Processed documents 7941 to 7960 (batch 398)
# Processed documents 7961 to 7980 (batch 399)
# Processed documents 7981 to 8000 (batch 400)
# Processed documents 8001 to 8020 (batch 401)
# Processed documents 8021 to 8040 (batch 402)
# Processed documents 8041 to 8060 (batch 403)
# Processed documents 8061 to 8080 (batch 404)
# Processed documents 8081 to 8100 (batch 405)
# Processed documents 8101 to 8120 (batch 406)
# Processed documents 8121 to 8140 (batch 407)
# Processed documents 8141 to 8160 (batch 408)
# Processed documents 8161 to 8180 (batch 409)
# Processed documents 8181 to 8200 (batch 410)
# Processed documents 8201 to 8220 (batch 411)
# Processed documents 8221 to 8240 (batch 412)
# Processed documents 8241 to 8260 (batch 413)
# Processed documents 8261 to 8280 (batch 414)
# Processed documents 8281 to 8300 (batch 415)
# Processed documents 8301 to 8320 (batch 416)
# Processed documents 8321 to 8340 (batch 417)
# Processed documents 8341 to 8360 (batch 418)
# Processed documents 8361 to 8380 (batch 419)
# Processed documents 8381 to 8400 (batch 420)
# Processed documents 8401 to 8420 (batch 421)
# Processed documents 8421 to 8440 (batch 422)
# Processed documents 8441 to 8460 (batch 423)
# Processed documents 8461 to 8480 (batch 424)
# Processed documents 8481 to 8500 (batch 425)
# Processed documents 8501 to 8520 (batch 426)
# Processed documents 8521 to 8540 (batch 427)
# Processed documents 8541 to 8560 (batch 428)
# Processed documents 8561 to 8580 (batch 429)
# Processed documents 8581 to 8600 (batch 430)
# Processed documents 8601 to 8620 (batch 431)
# Processed documents 8621 to 8640 (batch 432)
# Processed documents 8641 to 8660 (batch 433)
# Processed documents 8661 to 8680 (batch 434)
# Processed documents 8681 to 8700 (batch 435)
# Processed documents 8701 to 8720 (batch 436)
# Processed documents 8721 to 8740 (batch 437)
# Processed documents 8741 to 8760 (batch 438)
# Processed documents 8761 to 8780 (batch 439)
# Processed documents 8781 to 8800 (batch 440)
# Processed documents 8801 to 8820 (batch 441)
# Processed documents 8821 to 8837 (batch 442)
# Prepared 8837 documents with embeddings
# Batch 1: 100/100 documents succeeded
# Batch 2: 100/100 documents succeeded
# Batch 3: 100/100 documents succeeded
# Batch 4: 100/100 documents succeeded
# Batch 5: 100/100 documents succeeded
# Batch 6: 100/100 documents succeeded
# Batch 7: 100/100 documents succeeded
# Batch 8: 100/100 documents succeeded
# Batch 9: 100/100 documents succeeded
# Batch 10: 100/100 documents succeeded
# Batch 11: 100/100 documents succeeded
# Batch 12: 100/100 documents succeeded
# Batch 13: 100/100 documents succeeded
# Batch 14: 100/100 documents succeeded
# Batch 15: 100/100 documents succeeded
# Batch 16: 100/100 documents succeeded
# Batch 17: 100/100 documents succeeded
# Batch 18: 100/100 documents succeeded
# Batch 19: 100/100 documents succeeded
# Batch 20: 100/100 documents succeeded
# Batch 21: 100/100 documents succeeded
# Batch 22: 100/100 documents succeeded
# Batch 23: 100/100 documents succeeded
# Batch 24: 100/100 documents succeeded
# Batch 25: 100/100 documents succeeded
# Batch 26: 100/100 documents succeeded
# Batch 27: 100/100 documents succeeded
# Batch 28: 100/100 documents succeeded
# Batch 29: 100/100 documents succeeded
# Batch 30: 100/100 documents succeeded
# Batch 31: 100/100 documents succeeded
# Batch 32: 100/100 documents succeeded
# Batch 33: 100/100 documents succeeded
# Batch 34: 100/100 documents succeeded
# Batch 35: 100/100 documents succeeded
# Batch 36: 100/100 documents succeeded
# Batch 37: 100/100 documents succeeded
# Batch 38: 100/100 documents succeeded
# Batch 39: 100/100 documents succeeded
# Batch 40: 100/100 documents succeeded
# Batch 41: 100/100 documents succeeded
# Batch 42: 100/100 documents succeeded
# Batch 43: 100/100 documents succeeded
# Batch 44: 100/100 documents succeeded
# Batch 45: 100/100 documents succeeded
# Batch 46: 100/100 documents succeeded
# Batch 47: 100/100 documents succeeded
# Batch 48: 100/100 documents succeeded
# Batch 49: 100/100 documents succeeded
# Batch 50: 100/100 documents succeeded
# Batch 51: 100/100 documents succeeded
# Batch 52: 100/100 documents succeeded
# Batch 53: 100/100 documents succeeded
# Batch 54: 100/100 documents succeeded
# Batch 55: 100/100 documents succeeded
# Batch 56: 100/100 documents succeeded
# Batch 57: 100/100 documents succeeded
# Batch 58: 100/100 documents succeeded
# Batch 59: 100/100 documents succeeded
# Batch 60: 100/100 documents succeeded
# Batch 61: 100/100 documents succeeded
# Batch 62: 100/100 documents succeeded
# Batch 63: 100/100 documents succeeded
# Batch 64: 100/100 documents succeeded
# Batch 65: 100/100 documents succeeded
# Batch 66: 100/100 documents succeeded
# Batch 67: 100/100 documents succeeded
# Batch 68: 100/100 documents succeeded
# Batch 69: 100/100 documents succeeded
# Batch 70: 100/100 documents succeeded
# Batch 71: 100/100 documents succeeded
# Batch 72: 100/100 documents succeeded
# Batch 73: 100/100 documents succeeded
# Batch 74: 100/100 documents succeeded
# Batch 75: 100/100 documents succeeded
# Batch 76: 100/100 documents succeeded
# Batch 77: 100/100 documents succeeded
# Batch 78: 100/100 documents succeeded
# Batch 79: 100/100 documents succeeded
# Batch 80: 100/100 documents succeeded
# Batch 81: 100/100 documents succeeded
# Batch 82: 100/100 documents succeeded
# Batch 83: 100/100 documents succeeded
# Batch 84: 100/100 documents succeeded
# Batch 85: 100/100 documents succeeded
# Batch 86: 100/100 documents succeeded
# Batch 87: 100/100 documents succeeded
# Batch 88: 100/100 documents succeeded
# Batch 89: 37/37 documents succeeded
#
# Upload Summary:
# - Total documents: 8837
# - Successfully uploaded: 8837
# - Failed: 0

# %% [markdown]
# ### Search using vector similarity

# %%
# 已完成票单记录.xlsx
import pandas as pd
excel_path = "/home/azureuser/slm-fine-tune-private-domain-kb-generation/raw_documents/excel/已完成票单记录.xlsx"
df = pd.read_excel(excel_path)
# Convert all column headers to lowercase
df.columns = [col.lower().strip() for col in df.columns]

print(df.columns)


def prepare_kb_ticket_documents(df):
    # Ensure the DataFrame is not empty
    if df.empty:
        raise ValueError("The DataFrame is empty. Please provide a valid DataFrame.")

    # Check for required columns
    required_columns = ["问题描述", "处理方式"]
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        raise ValueError(f"The following required columns are missing: {', '.join(missing_columns)}")

    # Prepare documents for upload
    documents = []
    total_rows = len(df)

    # Prepare batches of questions and answers for efficient embedding generation
    batch_size = 20  # Azure OpenAI can handle multiple inputs in one API call
    for i in range(0, total_rows, batch_size):
        batch_end = min(i + batch_size, total_rows)
        batch_df = df.iloc[i:batch_end]
        
        # Prepare lists of questions and answers
        questions = [str(row["问题描述"]) if not pd.isna(row["问题描述"]) else "" for _, row in batch_df.iterrows()]
        answers = [str(row["处理方式"]) if not pd.isna(row["处理方式"]) else "" for _, row in batch_df.iterrows()]
        
        # Generate embeddings in batch
        question_embeddings = generate_embeddings_with_client(questions, aoai_client)
        answer_embeddings = generate_embeddings_with_client(answers, aoai_client)
        
        print(f"Processed documents {i+1} to {batch_end} (batch {i//batch_size + 1})")
        
        # Create documents with embeddings
        for j, (_, row) in enumerate(batch_df.iterrows()):
            idx = i + j
            document = {
                "id": f"kb_ticket_{idx}",
                "question": str(row["问题描述"]) if not pd.isna(row["问题描述"]) else "",
                "answer": str(row["处理方式"]) if not pd.isna(row["处理方式"]) else "",
                "applicationType": "",
                "question_embedding": question_embeddings[j],
                "answer_embedding": answer_embeddings[j]
            }
            documents.append(document)

    print(f"Prepared {len(documents)} documents with embeddings")
    return documents


# get documents from excel
kb_ai_gen_documents = prepare_kb_ai_gen_documents(df)
# upload documents into azure search
upload_document_into_azure_search(kb_ai_gen_documents, batch_size=100)

# %%
from azure.search.documents.models import VectorizedQuery

r = search_client.search(search_text=None, vector_queries=[
    VectorizedQuery(vector=[-2, -1, -1], k_nearest_neighbors=3, fields="embedding")])
for doc in r:
    print(f"id: {doc['id']}, score: {doc['@search.score']}")

# %% [markdown]
# ## Search a larger index

# %%
import azure.identity
import dotenv
import openai

dotenv.load_dotenv()

# Initialize Azure search variables
AZURE_SEARCH_SERVICE = os.getenv("AZURE_SEARCH_SERVICE")
AZURE_SEARCH_ENDPOINT = f"https://{AZURE_SEARCH_SERVICE}.search.windows.net"

# Set up OpenAI client based on environment variables
dotenv.load_dotenv()
AZURE_OPENAI_SERVICE = os.getenv("AZURE_OPENAI_SERVICE")
AZURE_OPENAI_ADA_DEPLOYMENT = os.getenv("AZURE_OPENAI_ADA_DEPLOYMENT")

token_provider = azure.identity.get_bearer_token_provider(azure_credential, "https://cognitiveservices.azure.com/.default")
openai_client = openai.AzureOpenAI(
    api_version="2023-07-01-preview",
    azure_endpoint=f"https://{AZURE_OPENAI_SERVICE}.openai.azure.com",
    azure_ad_token_provider=token_provider)

def get_embedding(text):
    get_embeddings_response = openai_client.embeddings.create(model=AZURE_OPENAI_ADA_DEPLOYMENT, input=text)
    return get_embeddings_response.data[0].embedding

# %%
AZURE_SEARCH_FULL_INDEX = "gptkbindex"
search_client = SearchClient(AZURE_SEARCH_ENDPOINT, AZURE_SEARCH_FULL_INDEX, credential=azure_credential)

search_query = "learning about underwater activities"
search_vector = get_embedding(search_query)
r = search_client.search(search_text=None, top=5, vector_queries=[
    VectorizedQuery(vector=search_vector, k_nearest_neighbors=5, fields="embedding")])
for doc in r:
    content = doc["content"].replace("\n", " ")[:150]
    print(f"Score: {doc['@search.score']:.5f}\tContent:{content}")
