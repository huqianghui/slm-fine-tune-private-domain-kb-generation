# %%
# local search
# !graphrag query \
--root ../graphragProcess \
--method local \
--query "what stage does T1N1M1 nasopharyngeal carcinoma belong to ?"
# Out:
# UsageError: Line magic function `%graphrag` not found.

# %%
# !graphrag query \
--root ../graphragProcess \
--method global \
--query "what main poits about the staging head and neck cancers?"
# Out:
# creating llm client with {'api_key': 'REDACTED,len=32', 'type': "azure_openai_chat", 'encoding_model': 'o200k_base', 'model': 'gpt-4o', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'frequency_penalty': 0.0, 'presence_penalty': 0.0, 'request_timeout': 180.0, 'api_base': 'https://openai-hu-east-us2.openai.azure.com', 'api_version': '2024-10-21', 'organization': None, 'proxy': None, 'audience': None, 'deployment_name': 'gpt-4o', 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25, 'responses': None}
#
# SUCCESS: Global Search Response:
# # Key Points on Staging Head and Neck Cancers
#
# Staging head and neck cancers is a critical process that informs prognosis, treatment planning, and overall patient management. The staging system has undergone significant updates to improve accuracy and clinical relevance. Below are the main points:
#
# ---
#
# ## 1. **The Role of the Clinical N (CN) Staging System**
# The Clinical N (CN) staging system is essential for evaluating regional lymph node involvement in head and neck cancers. It categorizes lymph nodes based on the extent of metastasis:
# - **N0**: No regional lymph node metastasis.
# - **N1**: Metastasis in a single ipsilateral lymph node, 3 cm or smaller, and without extranodal extension (ENE).
#
# Accurate lymph node staging is crucial for determining prognosis and tailoring treatment strategies [Data: Reports (13)].
#
# ---
#
# ## 2. **Updates in the 8th Edition of the AJCC Cancer Staging Manual**
# The 8th Edition of the AJCC Cancer Staging Manual introduces key updates to enhance staging precision:
# - **Depth of Invasion (DOI)**: Added to the T category, particularly relevant for oral cancers.
# - **Extranodal Extension (ENE)**: Incorporated into the N category, reflecting its critical prognostic value.
#
# These updates improve the ability to assess disease severity and guide treatment planning [Data: Reports (13, 11)].
#
# ---
#
# ## 3. **Extranodal Extension (ENE) as a Prognostic Factor**
# Extranodal extension (ENE) is a significant factor in determining prognosis. It refers to the spread of cancer beyond the lymph node capsule and is assessed through pathological examination. The inclusion of ENE in the N category underscores its importance in staging and treatment decisions [Data: Reports (13, 2)].
#
# ---
#
# ## 4. **Cervical Lymph Node Classification**
# Cervical lymph nodes are a critical component in staging head and neck cancers. They are classified into sublevels (Levels I-VII), which enhances precision in staging and allows for targeted treatment approaches. This classification is particularly relevant for cancers such as oral cancer [Data: Reports (17)].
#
# ---
#
# ## 5. **Anatomical Divisions of the Pharynx**
# The pharynx is divided into three regions—nasopharynx, oropharynx, and hypopharynx. These divisions are integral to disease-specific staging and enable tailored treatment strategies. The 8th Edition of the AJCC Cancer Staging Manual incorporates these anatomical distinctions to refine staging accuracy [Data: Reports (0)].
#
# ---
#
# ## Conclusion
# The staging of head and neck cancers has evolved to incorporate more precise and clinically relevant factors, such as depth of invasion and extranodal extension. These updates, along with detailed lymph node classification and anatomical considerations, ensure that staging systems provide a robust framework for prognosis and treatment planning. The 8th Edition of the AJCC Cancer Staging Manual represents a significant step forward in achieving these goals.

# %%
# !graphrag query \
--root ../graphragProcess \
--method drift \
--query "what main poits about the staging head and neck cancers?"
# Out:
# INFO: Vector Store Args: {
#     "type": "lancedb",
#     "db_uri": "/home/azureuser/slm-fine-tune-private-domain-kb-generation/graphragProcess/output/lancedb",
#     "container_name": "==== REDACTED ====",
#     "overwrite": true
# }
# creating llm client with {'api_key': 'REDACTED,len=32', 'type': "azure_openai_chat", 'encoding_model': 'o200k_base', 'model': 'gpt-4o', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'frequency_penalty': 0.0, 'presence_penalty': 0.0, 'request_timeout': 180.0, 'api_base': 'https://openai-hu-east-us2.openai.azure.com', 'api_version': '2024-10-21', 'organization': None, 'proxy': None, 'audience': None, 'deployment_name': 'gpt-4o', 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25, 'responses': None}
# creating embedding llm client with {'api_key': 'REDACTED,len=32', 'type': "azure_openai_embedding", 'encoding_model': 'o200k_base', 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'frequency_penalty': 0.0, 'presence_penalty': 0.0, 'request_timeout': 180.0, 'api_base': 'https://openai-hu-east-us2.openai.azure.com', 'api_version': '2024-02-15-preview', 'organization': None, 'proxy': None, 'audience': None, 'deployment_name': 'text-embedding-3-small', 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25, 'responses': None}
# /home/azureuser/slm-fine-tune-private-domain-kb-generation/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#
# SUCCESS: DRIFT Search Response:
# ### Overview of Staging Head and Neck Cancers
#
# Staging is a fundamental process in the management of head and neck cancers, offering a structured way to classify tumors and tailor treatments. The key elements in staging primarily focus on tumor size, lymph node involvement, and metastasis status, collectively referred to as the TNM classification system. This framework underpins the comprehension of disease progression, prognosis, and therapeutic direction.
#
# #### Primary Tumors and Anatomical Context
# Primary tumors of the head and neck serve as the central entity in understanding cancer development in this region. These cancers often arise in the mucosal surfaces of the upper aerodigestive tract, including the oral cavity, pharynx, larynx, and beyond. The anatomical complexity of the head and neck necessitates tailored diagnostic tools to precisely determine tumor location and size. Detailed anatomical mapping contributes to treatment planning and improves outcome accuracy.
#
# #### Staging Systems and Updates
# The American Joint Committee on Cancer (AJCC) Cancer Staging Manual provides a globally recognized framework for cancer staging. The 8th Edition has introduced critical updates for head and neck cancers, including staging specifics for the pharynx and head-and-neck-specific cutaneous malignancies. These updates also emphasize the importance of extranodal extension (ENE), where cancer spreads beyond lymph node boundaries, a significant factor for prognosis and treatment pathways.
#
# #### Cervical Lymph Nodes and Regional Spread
# Cervical lymph nodes play a pivotal role in the staging of head and neck cancers. They are divided into sublevels (Levels I-VII) to specify the anatomical spread of cancer, enhancing precision in classification and clinical decision-making. The involvement of lower-level nodes, such as Level IV or V, often signals advanced disease stages and necessitates more aggressive interventions. Moreover, cervical lymph node assessments become particularly vital in cases of cancer of unknown primary (CUP), where metastatic nodes are present without identifiable tumors.
#
# #### Integration of Staging and Research
# Staging systems integrate anatomical precision and clinical requirements, forming the cornerstone of oral cancer research. By offering a standardized staging language, these systems enable collaboration across research efforts, improving diagnosis, treatment customization, and patient care outcomes.
#
# #### Importance in Clinical Practice and Future Directions
# Accurate staging requires both clinical findings, like imaging, and pathological assessments, such as biopsies, spectroscopy, and histology. Advanced modalities like the Clinical N (CN) staging system refine the focus on lymph node involvement while encouraging specificity in mapping disease severity. Ongoing updates in staging models reflect progress in understanding head and neck cancer biology, laying the groundwork for innovative therapies and diagnostic protocols.
#
#
# ### Key Insights on Staging Head and Neck Cancers
#
# The staging of head and neck cancers involves an intricate process integrating anatomical, pathological, and clinical parameters aimed at assessing disease extent, guiding treatment, and predicting prognosis. One of the most critical components is the role of **regional lymph nodes** in staging systems. These lymph nodes are divided into seven anatomical levels, acting as a framework for stratifying disease based on cancer spread. Their involvement is categorized as part of the TNM (Tumor, Node, Metastasis) staging system, where specific levels of lymph node metastasis determine disease severity and necessary interventions. Advanced cases, especially those involving posterior triangle lymph nodes, signify higher risk and often poorer prognoses. These nodes are particularly susceptible to metastases from cancers of the posterior scalp, nasopharynx, and oropharynx, underscoring their clinical significance.
#
# Equally important is the **histopathologic examination**, which provides microscopic precision in staging. This technique identifies tumor foci within lymph nodes, allowing more accurate pathologic differentiation of cancer spread. Innovations such as immunohistochemistry and molecular markers are transforming capabilities in this domain, offering greater diagnostic clarity. Histopathologic assessments not only corroborate imaging findings for nodal involvement but also determine critical features like extranodal tumor extension, a recently recognized factor in the 8th Edition of the AJCC Cancer Staging Manual. This change enhances the prognostic value of the N (Node) category.
#
# The **8th Edition of the AJCC Cancer Staging Manual** significantly impacts the field by introducing updates such as depth of invasion and extranodal extension, emphasizing prediction of outcomes and tailored therapies. Depth of invasion, inserted into the T (Tumor) category, enables a better understanding of tumor aggressiveness, while extranodal tumor extension adds nuance to nodal staging, offering insights into systemic risk. Principles like hazard consistency (ensuring reliable risk categorization across patients) and clinical TNM staging (pretreatment evaluation) further align cancer staging with practical applications.
#
# Lastly, posterior triangle lymph nodes, bounded by anatomical structures like the trapezius, represent a segment of complex anatomical considerations linking staging to surgical precision. Comprehensive nodal evaluations, coupled with histopathologic insights and advanced staging frameworks, form the backbone of precise, effective cancer management.
#
# ### Relation of the Summary to the Query: Main Points About Staging of Head and Neck Cancers
#
# The summaries provided elaborate on crucial anatomical entities and their role in staging head and neck cancers, specifically highlighting the metastatic behavior of cancers in various lymph node groups and their implications for treatment and prognosis. Below are the main points derived:
#
# 1. **Lower Jugular Lymph Nodes**:
#    - These lymph nodes are pivotal in staging cancers originating primarily from regions such as the hypopharynx and thyroid. Their anatomical extent, from the cricoid cartilage to the clavicle, is essential for clinical and treatment planning. Lower jugular lymph node involvement significantly affects staging outcomes and influences the tailoring of therapeutic strategies including surgery and radiotherapy.
#    - The hypopharynx, a common site for such cancers, has frequent metastases to these lymph nodes, emphasizing their biological and clinical importance. HPV-negative oropharyngeal cancers also share similar metastatic behavior patterns.
#
# 2. **Upper Jugular Lymph Nodes**:
#    - Located around the upper third of the internal jugular vein and closely associated with the spinal accessory nerve, these nodes are high-risk sites for metastases from cancers of the oral cavity, nasopharynx, and larynx. Their involvement is integral to the TNM staging system's N-category evaluation.
#    - The nodes' anatomical relationships demand careful surgical planning during neck dissections to minimize complications, as well as precise radiological assessments to ensure accurate staging.
#
# 3. **Anterior Compartment Lymph Nodes**:
#    - This group encompasses the pretracheal, precricoid (Delphian), and paratracheal nodes, which are critical for staging thyroid, laryngeal, and cervical esophageal cancers. Specific examples include the Delphian node’s significance in thyroid cancer staging and its prognostic value.
#    - These nodes also underscore the interconnectedness of lymphatic drainage in metastasis paths, making them vital for comprehensive treatment strategies.
#
# 4. **Interconnectedness of Anatomical and Pathological Pathways**:
#    - All three lymphatic regions demonstrate the deep interrelation of anatomical landmarks and cancer progression pathways. This interconnectedness directly informs the staging process and guides decisions on multimodality treatment approaches such as surgery, radiation, and systemic therapies.
#
# 5. **Implications for Clinical Practice**:
#    - Involvement of these lymph nodes has direct implications for staging through the TNM system, prognosis determination, and therapeutic decisions. Radiologists and surgeons rely on these anatomical and clinical insights to optimize patient outcomes.
#
# Hence, these summaries provide a structured understanding of how the staging of head and neck cancers depends deeply on regional lymphatic involvement, anatomical boundaries, and connectivity to the sites of primary cancer.
#
# **Key Elements in Answering the Query**: Lower and upper jugular lymph nodes and anterior compartment lymph nodes are emphasized as critical for understanding the progression and staging of head and neck cancers, with a focus on their metastatic relationships and anatomical significance for treatment.
#
# ---
# This detailed analysis directly addresses the query by presenting the main points about relevant anatomical structures, cancer progression pathways, and staging implications in head and neck cancers.
#
# ### Key Points About Staging Head and Neck Cancers
#
# The staging of head and neck cancers involves multiple systems and factors to evaluate the extent and progression of the disease, utilizing detailed anatomical, histopathological, and clinical features. Communities focusing on this topic emphasize the role of lymph nodes, extranodal extension (ENE), and standardized cancer staging systems like the AJCC Cancer Staging Manual. Here are some key aspects derived from the most relevant communities:
#
# #### The Role of Lymph Nodes in Staging
# Lymph nodes play a central role in staging head and neck cancers, particularly the superior mediastinal and paratracheal lymph nodes. These nodes are critical entities due to their high risk of involvement in thyroid and esophageal cancers, which are considered subsets of head and neck cancers. Superior mediastinal lymph nodes, including paratracheal nodes, serve as pathways for metastasis, making their assessment essential for accurate staging and treatment planning. Their relationship highlights how interconnected lymphatic structures in the head and neck region are, and their role in spreading disease underpins the progression of cancer staging.
#
# #### Extranodal Extension (ENE) as a Prognostic Factor
# Extranodal extension (ENE) is a defining feature in cases involving cervical lymph nodes, signifying cancer spread beyond the lymph node capsule. It is recognized in the 8th Edition of the AJCC Cancer Staging Manual and serves as a critical prognostic factor for advanced disease. ENE also impacts anatomical structures like cranial nerves, the brachial plexus, and the sympathetic trunk, underscoring its significance in determining disease severity. Its identification through histopathological characterization helps in refining staging accuracy and guiding more personalized treatment decisions.
#
# #### Standardized Staging Systems
# Standardized systems, such as those proposed by the AJCC and UICC, provide the framework for staging head and neck cancers. The Cancer Staging Manual, 8th Edition, incorporates anatomical, molecular markers, and prognostic factors for an enhanced staging process. This harmonization ensures consistency in cancer care globally, enabling comparative studies and effective clinical trial designs. Improvements in staging systems offer more personalized treatment approaches and better predict outcomes, particularly relevant for tumors in high-risk areas, such as oral or lymphatic structures in the head and neck.
#
# #### Implications for Treatment Planning
# The integration of lymphatic node involvement, ENE, and global staging alignment has direct implications for treatment planning. Accurate staging determines the eligibility for surgical intervention, radiotherapy, or systemic therapies. In cases where advanced ENE complicates prognosis, a multidisciplinary approach leveraging the staging data is crucial for creating targeted treatment plans that address disease spread while optimizing patient quality of life. This framework provides opportunities for enhanced clinical decision-making across stages of cancer.
#
# #### Conclusion
# The staging of head and neck cancers is a multifaceted process that involves understanding lymph node involvement, recognizing extranodal extension, and utilizing standardized global criteria. These elements together shape the treatment paradigms and prognostic expectations for impacted patients, making staging a cornerstone of cancer care for these diseases.
#
#
# ### Relevance of Staging Head and Neck Cancers: Key Points
#
# The staging of head and neck cancers is a critical component in understanding the progression of the disease, determining treatment strategies, and predicting outcomes. Central to staging are the lymph node regions, as these often represent the first sites of metastases. The following key points summarize the critical aspects of staging related to the lymph nodes:
#
# 1. **Middle Jugular Lymph Nodes and Metastases**:
#    These lymph nodes are frequently involved in metastases from cancers originating in the oral cavity, oropharynx, hypopharynx, larynx, and nasopharynx. Their anatomical location around the middle third of the internal jugular vein (bounded by the sternocleidomastoid muscle and the cricoid cartilage) makes them pivotal for cancer staging and treatment decisions. Clinicians rely on imaging and surgical procedures to assess the extent of nodal involvement, which can indicate disease advancement and necessitate aggressive treatments, such as neck dissection or adjuvant therapies.
#
# 2. **Submandibular Lymph Nodes and Their Boundaries**:
#    These nodes are high-risk sites for metastases, particularly for cancers in the oral cavity, anterior nasal cavity, and midface. Their proximity to structural boundaries like the mandible and the stylohyoid muscle underscores the complexity of staging and treatment. Their involvement is especially relevant in TNM classifications, highlighting the need for precise imaging and surgical planning to optimize patient outcomes while minimizing complications.
#
# 3. **Submental Lymph Nodes and Cancer Spread**:
#    The submental lymph nodes frequently exhibit metastases from cancers arising in the anterior oral cavity, including the floor of the mouth and tongue. Bounded by the digastric muscles and the hyoid bone, their involvement in staging often results in an upstage of the cancer, necessitating comprehensive interventions such as neck dissections and adjuvant therapy.
#
# 4. **Importance of Anatomical Boundaries**:
#    Understanding anatomical boundaries, such as the sternocleidomastoid muscle, cricoid cartilage, mandible, digastric muscles, and hyoid bone, is essential for staging. These landmarks provide critical guidance during imaging, biopsies, and surgical procedures to assess disease extent accurately.
#
# 5. **Clinical Implications**:
#    The presence of lymph node metastases often alters the cancer stage, which directly affects the treatment approach and prognosis. Comprehensive evaluation, including the use of advanced imaging technologies (e.g., CT, MRI, PET scans), is essential for identifying lymph node involvement. Late-stage nodal involvement is an indicator of advanced disease and may require multimodal treatment approaches, including surgery, chemotherapy, and radiation.
#
# These points highlight the interconnectedness of anatomical landmarks, cancer progression, and clinical strategies, ensuring that staging remains the cornerstone of effective treatment for head and neck cancers.
